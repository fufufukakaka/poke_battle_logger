# %%
import asyncio
import concurrent.futures
import dataclasses
import re
import threading
from collections import Counter
from typing import Dict, List, Tuple, Union, cast

import cv2
import numpy as np
import yt_dlp
from fastapi import WebSocket

from poke_battle_logger.batch.data_builder import DataBuilder
from poke_battle_logger.batch.extractor import Extractor
from poke_battle_logger.batch.frame_compressor import (
    frame_compress,
    message_frame_compress,
)
from poke_battle_logger.batch.frame_detector import FrameDetector
from poke_battle_logger.batch.pokemon_extractor import PokemonExtractor
from poke_battle_logger.database.database_handler import DatabaseHandler
from poke_battle_logger.types import StatusByWebsocket
from tqdm.auto import tqdm
import matplotlib.pyplot as plt
import pytesseract
import editdistance
from poke_battle_logger.batch.pokemon_name_window_extractor import (
    EDIT_DISTANCE_THRESHOLD,
    PokemonNameWindowExtractor,
)

# %%
import os
os.environ["TESSDATA_PREFIX"] = "/opt/brew/Cellar/tesseract/5.3.0_1/share/tessdata_best/"

# %%
video_id = "NrqfXhpwDX8"
language = "en"
trainer_id = 1

# %%
video = cv2.VideoCapture(f"video/{video_id}.mp4")

frame_detector = FrameDetector(language)
extractor = Extractor(language)
pokemon_extractor = PokemonExtractor()

first_ranking_frames = []
select_done_frames = []
standing_by_frames = []
level_50_frames = []
ranking_frames = []
win_or_lost_frames = []
message_window_frames = []

print("read_video")
total_frames = int(video.get(cv2.CAP_PROP_FRAME_COUNT))
for i in range(total_frames):
    ret, frame = video.read()
    if ret:
        # message window
        if frame_detector.is_message_window_frame(frame):
            message_window_frames.append(i)
            continue

        # level_50
        if frame_detector.is_level_50_frame(frame):
            level_50_frames.append(i)
            continue

        # first ranking
        if frame_detector.is_first_ranking_frame(frame):
            first_ranking_frames.append(i)
            continue

        # select done
        if frame_detector.is_select_done_frame(frame):
            select_done_frames.append(i)
            continue

        # standing_by
        if frame_detector.is_standing_by_frame(frame):
            standing_by_frames.append(i)
            continue

        # ranking
        if frame_detector.is_ranking_frame(frame):
            ranking_frames.append(i)
            continue

        # win_or_lost
        if frame_detector.is_win_or_lost_frame(frame):
            win_or_lost_frames.append(i)
            continue
    else:
        continue

# compress
print("compress")
compressed_first_ranking_frames = frame_compress(first_ranking_frames)
compressed_select_done_frames = frame_compress(select_done_frames)
compressed_standing_by_frames = frame_compress(
    standing_by_frames, ignore_short_frames=True
)
compressed_level_50_frames = frame_compress(level_50_frames)
compressed_ranking_frames = frame_compress(ranking_frames)
compressed_win_or_lost_frames = frame_compress(win_or_lost_frames)
compressed_message_window_frames = message_frame_compress(
    message_window_frames, frame_threshold=3
)

# 開始時のランクを検出(OCR)
print("rank1")
rank_numbers = {}
first_ranking_frame_number = compressed_first_ranking_frames[0][-5]
video.set(cv2.CAP_PROP_POS_FRAMES, first_ranking_frame_number - 1)
_, _first_ranking_frame = video.read()
rank_numbers[first_ranking_frame_number] = extractor.extract_first_rank_number(
    _first_ranking_frame
)

# ランクを検出(OCR)
print("rank2")
for ranking_frame_numbers in compressed_ranking_frames:
    ranking_frame_number = ranking_frame_numbers[-5]
    video.set(cv2.CAP_PROP_POS_FRAMES, ranking_frame_number - 1)
    _, _ranking_frame = video.read()
    rank_numbers[ranking_frame_number] = extractor.extract_rank_number(
        _ranking_frame
    )

# 順位が変動しなかった場合、その値を rank_numbers から削除する
rank_frames = list(rank_numbers.keys())
for i in range(len(rank_numbers) - 1):
    _ranking_frame_number = rank_frames[i]
    _next_ranking_frame_number = rank_frames[i + 1]

    if (
        rank_numbers[_ranking_frame_number]
        == rank_numbers[_next_ranking_frame_number]
    ):
        del rank_numbers[_ranking_frame_number]

# 対戦の始点と終点を定義する
print("start,end")
battle_start_end_frame_numbers: List[Tuple[int, int]] = []
rank_frames = list(rank_numbers.keys())
for i in range(len(compressed_standing_by_frames)):
    _standing_by_frames = compressed_standing_by_frames[i]
    _standing_by_frame_number = _standing_by_frames[-1]

    # チーム選択からの場合(最初の順位表示なし)
    if len(compressed_standing_by_frames) == len(rank_numbers):
        _ranking_frame = rank_frames[i]
    else:
        # バトルスタジアム入場(最初に表示された順位がある)からの場合
        _ranking_frame = rank_frames[i + 1]

    if _standing_by_frame_number < _ranking_frame:
        battle_start_end_frame_numbers.append(
            (_standing_by_frame_number, _ranking_frame)
        )

# ポケモンの選出順を抽出する
pokemon_select_order = {}
print("order")
for i in range(len(compressed_select_done_frames)):
    _select_done_frames = compressed_select_done_frames[i]
    _select_done_frame_number = _select_done_frames[-5]

    video.set(cv2.CAP_PROP_POS_FRAMES, _select_done_frame_number - 1)
    _, _select_done_frame = video.read()

    _pokemon_select_order = extractor.extract_pokemon_select_numbers(
        _select_done_frame
    )
    pokemon_select_order[_select_done_frame_number] = _pokemon_select_order

# 6vs6のポケモンを抽出する
print("6vs6")
pre_battle_pokemons: Dict[int, Dict[str, List[str]]] = {}
is_exist_unknown_pokemon_list1 = []
for i in range(len(compressed_standing_by_frames)):
    _standing_by_frames = compressed_standing_by_frames[i]
    if len(_standing_by_frames) == 1:
        continue
    _standing_by_frame_number = _standing_by_frames[-1]

    video.set(cv2.CAP_PROP_POS_FRAMES, _standing_by_frame_number - 1)
    _, _standing_by_frame = video.read()
    _standing_by_frame = cast(np.ndarray, _standing_by_frame)

    (
        your_pokemon_names,
        opponent_pokemon_names,
        _is_exist_unknown_pokemon,
    ) = pokemon_extractor.extract_pre_battle_pokemons(_standing_by_frame)
    pre_battle_pokemons[_standing_by_frame_number] = {
        "your_pokemon_names": your_pokemon_names,
        "opponent_pokemon_names": opponent_pokemon_names,
    }
    is_exist_unknown_pokemon_list1.append(_is_exist_unknown_pokemon)

# 対戦中のポケモンを抽出する
print("3vs3")
battle_pokemons: List[Dict[str, Union[str, int]]] = []
is_exist_unknown_pokemon_list2 = []
for level_50_frame_numbers in compressed_level_50_frames:
    _level_50_frame_number = level_50_frame_numbers[-1]
    video.set(cv2.CAP_PROP_POS_FRAMES, _level_50_frame_number - 1)
    _, _level_50_frame = video.read()

    (
        your_pokemon_name,
        opponent_pokemon_name,
        _is_exist_unknown_pokemon,
    ) = extractor.extract_pokemon_name_in_battle(_level_50_frame)

    battle_pokemons.append(
        {
            "frame_number": _level_50_frame_number,
            "your_pokemon_name": your_pokemon_name,
            "opponent_pokemon_name": opponent_pokemon_name,
        },
    )
    is_exist_unknown_pokemon_list2.append(_is_exist_unknown_pokemon)

if any(is_exist_unknown_pokemon_list1) or any(is_exist_unknown_pokemon_list2):
    raise ValueError

# 勝ち負けを検出
# 間違いやすいので、周辺最大10フレームを見て判断する。全て unknown の時は弾く
print("win lose")
win_or_lost = {}
for win_or_lost_frame_numbers in compressed_win_or_lost_frames:
    if len(win_or_lost_frame_numbers) > 3:
        _win_or_lost_results = []
        for idx in range(max(10, len(win_or_lost_frame_numbers))):
            _win_or_lost_frame_number = win_or_lost_frame_numbers[-1] - idx
            video.set(cv2.CAP_PROP_POS_FRAMES, _win_or_lost_frame_number - 1)
            _, _win_or_lost_frame = video.read()
            _win_or_lost_result = extractor.extract_win_or_lost(
                _win_or_lost_frame
            )
            _win_or_lost_results.append(_win_or_lost_result)

        _win_or_lost_results = [
            v for v in _win_or_lost_results if v != "unknown"
        ]
        win_or_lost_frame_number = win_or_lost_frame_numbers[-1]
        if len(_win_or_lost_results) == 0:
            win_or_lost[win_or_lost_frame_number] = "unknown"
            continue
        win_or_lost_result = Counter(_win_or_lost_results).most_common()[0][0]
        win_or_lost_frame_number = win_or_lost_frame_numbers[-1]
        win_or_lost[win_or_lost_frame_number] = win_or_lost_result

# メッセージの文字認識(OCR)
print("message")
messages = {}
for message_frame_numbers in compressed_message_window_frames:
    message_frame_number = message_frame_numbers[-1]
    video.set(cv2.CAP_PROP_POS_FRAMES, message_frame_number - 1)
    _, _message_frame = video.read()
    _message = extractor.extract_message(_message_frame)
    if _message is not None:
        messages[message_frame_number] = _message

# build formatted data
data_builder = DataBuilder(
    trainer_id=trainer_id,
    video_id=video_id,
    battle_start_end_frame_numbers=battle_start_end_frame_numbers,
    battle_pokemons=battle_pokemons,
    pre_battle_pokemons=pre_battle_pokemons,
    pokemon_select_order=pokemon_select_order,
    rank_numbers=rank_numbers,
    messages=messages,
    win_or_lost=win_or_lost,
)

(
    battles,
    battle_logs,
    modified_pre_battle_pokemons,
    modified_in_battle_pokemons,
    modified_messages,
) = data_builder.build()
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/12.8k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/348M [00:00<?, ?B/s]
# /Users/yusuke-fukasawa/Library/Caches/pypoetry/virtualenvs/poke-battle-logger-xYV7PrtE-py3.10/lib/python3.10/site-packages/transformers/models/vit/feature_extraction_vit.py:28: FutureWarning: The class ViTFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use ViTImageProcessor instead.
#   warnings.warn(
# read_video
# compress
# rank1
# rank2
# [h264 @ 0x2a5e0f290] Missing reference picture, default is 0
# [h264 @ 0x2a5e0f290] decode_slice_header error
# [h264 @ 0x2a5e0f290] Missing reference picture, default is 0
# [h264 @ 0x2a5e0f290] decode_slice_header error
# start,end
# order
# 6vs6
# [h264 @ 0x2a5e0f290] Missing reference picture, default is 0
# [h264 @ 0x2a5e0f290] decode_slice_header error
# 3vs3
# [h264 @ 0x2a5e0f290] Missing reference picture, default is 0
# [h264 @ 0x2a5e0f290] decode_slice_header error
# [h264 @ 0x2a5e0f290] Missing reference picture, default is 0
# [h264 @ 0x2a5e0f290] decode_slice_header error
# [h264 @ 0x2a5e0f290] Missing reference picture, default is 0
# [h264 @ 0x2a5e0f290] decode_slice_header error
# [h264 @ 0x2a5e0f290] Missing reference picture, default is 0
# [h264 @ 0x2a5e0f290] decode_slice_header error
# [h264 @ 0x2a5e0f290] Missing reference picture, default is 0
# [h264 @ 0x2a5e0f290] decode_slice_header error
# [h264 @ 0x2a5e0f290] Missing reference picture, default is 0
# [h264 @ 0x2a5e0f290] decode_slice_header error
# [h264 @ 0x2a5e0f290] Missing reference picture, default is 0
# [h264 @ 0x2a5e0f290] decode_slice_header error
# [h264 @ 0x2a5e0f290] Missing reference picture, default is 0
# [h264 @ 0x2a5e0f290] decode_slice_header error
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 181
#     178     is_exist_unknown_pokemon_list2.append(_is_exist_unknown_pokemon)
#     180 if any(is_exist_unknown_pokemon_list1) or any(is_exist_unknown_pokemon_list2):
# --> 181     raise ValueError
#     183 # 勝ち負けを検出
#     184 # 間違いやすいので、周辺最大10フレームを見て判断する。全て unknown の時は弾く
#     185 print("win lose")
#
# ValueError:

# %%
battles
# Out:
# [Battle(battle_id='a5a0441f-8c68-5d97-9754-d07e27a659a6', trainer_id=1),
#  Battle(battle_id='b2f19678-e67c-5816-8e23-2351765453cb', trainer_id=1),
#  Battle(battle_id='75466ffa-c378-5e9b-81b6-74e0f038cc43', trainer_id=1),
#  Battle(battle_id='275bd102-d57c-58c1-889e-f685f802e0f2', trainer_id=1)]

# %%
battle_logs
# Out:
# [BattleLog(battle_id='89b0f3a2-7815-57c6-ace1-14e45d1cfb67', created_at='2023-07-16 22:51:31', win_or_lose='lose', next_rank=22450, your_team='ヒスイドレディア,ノココッチ,ヒードラン,ハバタクカミ,パオジアン,ウォッシュロトム', opponent_team='霊獣ランドロス,パオジアン,へイラッシャ,ウーラオス,サーフゴー,ヒードラン', your_pokemon_1='ノココッチ', your_pokemon_2='ヒスイドレディア', your_pokemon_3='ウォッシュロトム', opponent_pokemon_1='ウーラオス', opponent_pokemon_2='ヒードラン', opponent_pokemon_3='ヘイラッシャ', video='http://youtube.com/watch?v=ZRZnTBB-698&t=90'),
#  BattleLog(battle_id='9a60a6bb-356d-57e3-871e-1724d692fed1', created_at='2023-07-16 23:05:57', win_or_lose='lose', next_rank=26479, your_team='ヒスイドレディア,ノココッチ,ヒードラン,ハバタクカミ,パオジアン,ウォッシュロトム', opponent_team='テツノツツミ,ヒスイヌメルゴン,マリルリ,ハバタクカミ,ガチグマ,霊獣ボルトロス', your_pokemon_1='ノココッチ', your_pokemon_2='ヒスイドレディア', your_pokemon_3='パオジアン', opponent_pokemon_1='マリルリ', opponent_pokemon_2='ハバタクカミ', opponent_pokemon_3='Unseen', video='http://youtube.com/watch?v=ZRZnTBB-698&t=956'),
#  BattleLog(battle_id='e4437a6b-8e26-5985-9c19-6020fabbfcf8', created_at='2023-07-16 23:11:12', win_or_lose='win', next_rank=23112, your_team='ヒスイドレディア,ウーラオス,ヒードラン,ハバタクカミ,パオジアン,ウォッシュロトム', opponent_team='カイリュー,ベトベトン,ゲンガー,パルシェン,ヤドラン,サンダー', your_pokemon_1='ヒスイドレディア', your_pokemon_2='ウォッシュロトム', your_pokemon_3='ヒードラン', opponent_pokemon_1='ベトベトン', opponent_pokemon_2='パルシェン', opponent_pokemon_3='ヤドラン', video='http://youtube.com/watch?v=ZRZnTBB-698&t=1271'),
#  BattleLog(battle_id='bd8a3aa0-4261-5337-a391-2c4010ea99bb', created_at='2023-07-16 23:21:24', win_or_lose='win', next_rank=19224, your_team='ヒスイドレディア,ウーラオス,ヒードラン,ハバタクカミ,パオジアン,ウォッシュロトム', opponent_team='パオジアン,ヒードラン,カイリュー,ハバタクカミ,ウォッシュロトム,霊獣ランドロス', your_pokemon_1='ヒスイドレディア', your_pokemon_2='ヒードラン', your_pokemon_3='ハバタクカミ', opponent_pokemon_1='ハバタクカミ', opponent_pokemon_2='ウォッシュロトム', opponent_pokemon_3='霊獣ランドロス', video='http://youtube.com/watch?v=ZRZnTBB-698&t=1883')]

# %%
import pandas as pd

# Convert list of InBattlePokemon and Message objects to dataframes
df_in_battle_pokemon = pd.DataFrame([obj.__dict__ for obj in modified_in_battle_pokemons])
df_messages = pd.DataFrame([obj.__dict__ for obj in modified_messages])

# %%
df_messages.head(50)
# Out:
#                                battle_id  frame_number  \
# 0   b65de106-caf1-5d60-a127-499242a0e687          4635
# 1   b65de106-caf1-5d60-a127-499242a0e687          5055
# 2   b65de106-caf1-5d60-a127-499242a0e687          5219
# 3   b65de106-caf1-5d60-a127-499242a0e687          5296
# 4   b65de106-caf1-5d60-a127-499242a0e687          5560
# 5   b65de106-caf1-5d60-a127-499242a0e687          5652
# 6   b65de106-caf1-5d60-a127-499242a0e687          5704
# 7   b65de106-caf1-5d60-a127-499242a0e687          5799
# 8   b65de106-caf1-5d60-a127-499242a0e687          5868
# 9   b65de106-caf1-5d60-a127-499242a0e687          6129
# 10  b65de106-caf1-5d60-a127-499242a0e687          9124
# 11  b65de106-caf1-5d60-a127-499242a0e687          9191
# 12  b65de106-caf1-5d60-a127-499242a0e687          9259
# 13  b65de106-caf1-5d60-a127-499242a0e687          9316
# 14  b65de106-caf1-5d60-a127-499242a0e687          9739
# 15  b65de106-caf1-5d60-a127-499242a0e687         10067
# 16  b65de106-caf1-5d60-a127-499242a0e687         12273
# 17  b65de106-caf1-5d60-a127-499242a0e687         12930
# 18  b65de106-caf1-5d60-a127-499242a0e687         13037
# 19  b65de106-caf1-5d60-a127-499242a0e687         14573
# 20  b65de106-caf1-5d60-a127-499242a0e687         14639
# 21  b65de106-caf1-5d60-a127-499242a0e687         15183
# 22  b65de106-caf1-5d60-a127-499242a0e687         15620
# 23  b65de106-caf1-5d60-a127-499242a0e687         15794
# 24  b65de106-caf1-5d60-a127-499242a0e687         16055
# 25  b65de106-caf1-5d60-a127-499242a0e687         16284
# 26  b65de106-caf1-5d60-a127-499242a0e687         16408
# 27  b65de106-caf1-5d60-a127-499242a0e687         16545
# 28  b65de106-caf1-5d60-a127-499242a0e687         17224
# 29  b65de106-caf1-5d60-a127-499242a0e687         17339
# 30  b65de106-caf1-5d60-a127-499242a0e687         17488
# 31  688a2326-1fe5-5cea-935f-634c363e86e2         23131
# 32  688a2326-1fe5-5cea-935f-634c363e86e2         23225
# 33  688a2326-1fe5-5cea-935f-634c363e86e2         23526
# 34  688a2326-1fe5-5cea-935f-634c363e86e2         23551
# 35  688a2326-1fe5-5cea-935f-634c363e86e2         23661
# 36  688a2326-1fe5-5cea-935f-634c363e86e2         23756
# 37  688a2326-1fe5-5cea-935f-634c363e86e2         24031
# 38  688a2326-1fe5-5cea-935f-634c363e86e2         24188
# 39  688a2326-1fe5-5cea-935f-634c363e86e2         24494
# 40  688a2326-1fe5-5cea-935f-634c363e86e2         24571
# 41  688a2326-1fe5-5cea-935f-634c363e86e2         24799
# 42  688a2326-1fe5-5cea-935f-634c363e86e2         24937
# 43  688a2326-1fe5-5cea-935f-634c363e86e2         25129
# 44  688a2326-1fe5-5cea-935f-634c363e86e2         25286
# 45  688a2326-1fe5-5cea-935f-634c363e86e2         25401
# 46  688a2326-1fe5-5cea-935f-634c363e86e2         25553
# 47  688a2326-1fe5-5cea-935f-634c363e86e2         25626
# 48  688a2326-1fe5-5cea-935f-634c363e86e2         25764
# 49  688a2326-1fe5-5cea-935f-634c363e86e2         26919
#
#                                               message
# 0                                      Gol Dragapult!
# 1                        Dragapult used Light Screen!
# 2              The opposing テツ ノ ツ ツ ミ used Ice Beam!
# 3                               It's super effective!
# 4                             Dragapult used Reflect!
# 5   Reflect made your team stronger against physic...
# 6              The opposing テツ ノ ツ ツ ミ used Ice Beam!
# 7                               It's super effective!
# 8                                  Dragapult fainted!
# 9                                      Gol ドレ ディ ア |!
# 10                              It's super effective!
# 11                       The Pokémon was hit 5 times!
# 12               The opposing ラン ドロ ス used Rock Tomb!
# 13                              It's super effective!
# 14                              It's super effective!
# 15                        The Pokémon was hit 1 time!
# 16             The opposing ヤ ド キ ング used Acid Spray!
# 17           The opposing ヤ ド キ ング used Future Sight!
# 18           The opposing ヤ ド キ ング foresaw an attack!
# 19                         It's not very effective...
# 20                 Your team’s Light Screen wore off!
# 21          The opposing ヤ ド キ ング avoided the attack!
# 22                      Your team’s Reflect wore off!
# 23                           Go for it, Flutter Mane!
# 24               Flutter Mane's Speed was heightened!
# 25                     Flutter Mane used Shadow Ball!
# 26                              It's super effective!
# 27                     The opposing ヤ ド キ ング fainted!
# 28                       Flutter Mane used Moonblast!
# 29                The opposing 7 デ ツ ノ ツ ツ ミ fainted!
# 30                                 You defeated Up A!
# 31                           mayu sent out Chien-Pao!
# 32                                     Gol Dragapult!
# 33          The opposing Chien-Pao used Sucker Punch!
# 34                                     But it failed!
# 35                            Dragapult used Reflect!
# 36  Reflect made your team stronger against physic...
# 37                           mayu withdrew Chien-Pao!
# 38                        mayu sent out 八 八 ダク ワカ ヨリ!
# 39  The opposing /\/\F ZT 73="s Speed was heightened!
# 40                        Dragapult used Will-O-Wisp!
# 41              The opposing /\/\F J 71 = was burned!
# 42     The opposing /\/\F 771 = was hurt by its burn!
# 43                              Dragapult, come back!
# 44                                     Gol ヒー ドラ フン !
# 45             The opposing 八 バ タク カミ used Calm Mind!
# 46           The opposing /\J\F 7 F3="s Sp. Atk rose!
# 47             The opposing /\JXFTF3=’s Sp. Def rose!
# 48      The opposing 八 パ タク カ ミ was hurt by its burn!
# 49              The opposing ハバ タク カミ used Calm Mind!

# %%
# Add a 'next_frame_number' column to the battle log
df_in_battle_pokemon = df_in_battle_pokemon.sort_values(by=['battle_id', 'turn'])
df_in_battle_pokemon['next_frame_number'] = df_in_battle_pokemon.groupby('battle_id')['frame_number'].shift(-1)

# Join the message log to the battle log
df_messages2 = pd.merge_asof(
    df_messages.sort_values('frame_number'), 
    df_in_battle_pokemon.sort_values('frame_number'), 
    left_on='frame_number', 
    right_on='frame_number',
    by='battle_id',
    direction='backward'
)

# %%
df_messages2.head(30)
# Out:
#                                battle_id  frame_number  \
# 0   b65de106-caf1-5d60-a127-499242a0e687          4635
# 1   b65de106-caf1-5d60-a127-499242a0e687          5055
# 2   b65de106-caf1-5d60-a127-499242a0e687          5219
# 3   b65de106-caf1-5d60-a127-499242a0e687          5296
# 4   b65de106-caf1-5d60-a127-499242a0e687          5560
# 5   b65de106-caf1-5d60-a127-499242a0e687          5652
# 6   b65de106-caf1-5d60-a127-499242a0e687          5704
# 7   b65de106-caf1-5d60-a127-499242a0e687          5799
# 8   b65de106-caf1-5d60-a127-499242a0e687          5868
# 9   b65de106-caf1-5d60-a127-499242a0e687          6129
# 10  b65de106-caf1-5d60-a127-499242a0e687          9124
# 11  b65de106-caf1-5d60-a127-499242a0e687          9191
# 12  b65de106-caf1-5d60-a127-499242a0e687          9259
# 13  b65de106-caf1-5d60-a127-499242a0e687          9316
# 14  b65de106-caf1-5d60-a127-499242a0e687          9739
# 15  b65de106-caf1-5d60-a127-499242a0e687         10067
# 16  b65de106-caf1-5d60-a127-499242a0e687         12273
# 17  b65de106-caf1-5d60-a127-499242a0e687         12930
# 18  b65de106-caf1-5d60-a127-499242a0e687         13037
# 19  b65de106-caf1-5d60-a127-499242a0e687         14573
# 20  b65de106-caf1-5d60-a127-499242a0e687         14639
# 21  b65de106-caf1-5d60-a127-499242a0e687         15183
# 22  b65de106-caf1-5d60-a127-499242a0e687         15620
# 23  b65de106-caf1-5d60-a127-499242a0e687         15794
# 24  b65de106-caf1-5d60-a127-499242a0e687         16055
# 25  b65de106-caf1-5d60-a127-499242a0e687         16284
# 26  b65de106-caf1-5d60-a127-499242a0e687         16408
# 27  b65de106-caf1-5d60-a127-499242a0e687         16545
# 28  b65de106-caf1-5d60-a127-499242a0e687         17224
# 29  b65de106-caf1-5d60-a127-499242a0e687         17339
#
#                                               message  turn your_pokemon_name  \
# 0                                      Gol Dragapult!   NaN               NaN
# 1                        Dragapult used Light Screen!   1.0             ドラパルト
# 2              The opposing テツ ノ ツ ツ ミ used Ice Beam!   1.0             ドラパルト
# 3                               It's super effective!   1.0             ドラパルト
# 4                             Dragapult used Reflect!   2.0             ドラパルト
# 5   Reflect made your team stronger against physic...   2.0             ドラパルト
# 6              The opposing テツ ノ ツ ツ ミ used Ice Beam!   2.0             ドラパルト
# 7                               It's super effective!   2.0             ドラパルト
# 8                                  Dragapult fainted!   2.0             ドラパルト
# 9                                      Gol ドレ ディ ア |!   2.0             ドラパルト
# 10                              It's super effective!   4.0          ヒスイドレディア
# 11                       The Pokémon was hit 5 times!   4.0          ヒスイドレディア
# 12               The opposing ラン ドロ ス used Rock Tomb!   4.0          ヒスイドレディア
# 13                              It's super effective!   4.0          ヒスイドレディア
# 14                              It's super effective!   5.0          ヒスイドレディア
# 15                        The Pokémon was hit 1 time!   5.0          ヒスイドレディア
# 16             The opposing ヤ ド キ ング used Acid Spray!   7.0          ヒスイドレディア
# 17           The opposing ヤ ド キ ング used Future Sight!   8.0          ヒスイドレディア
# 18           The opposing ヤ ド キ ング foresaw an attack!   8.0          ヒスイドレディア
# 19                         It's not very effective...   9.0          ヒスイドレディア
# 20                 Your team’s Light Screen wore off!   9.0          ヒスイドレディア
# 21          The opposing ヤ ド キ ング avoided the attack!  10.0          ヒスイドレディア
# 22                      Your team’s Reflect wore off!  10.0          ヒスイドレディア
# 23                           Go for it, Flutter Mane!  10.0          ヒスイドレディア
# 24               Flutter Mane's Speed was heightened!  10.0          ヒスイドレディア
# 25                     Flutter Mane used Shadow Ball!  11.0            ハバタクカミ
# 26                              It's super effective!  11.0            ハバタクカミ
# 27                     The opposing ヤ ド キ ング fainted!  11.0            ハバタクカミ
# 28                       Flutter Mane used Moonblast!  12.0            ハバタクカミ
# 29                The opposing 7 デ ツ ノ ツ ツ ミ fainted!  12.0            ハバタクカミ
#
#    opponent_pokemon_name  next_frame_number
# 0                    NaN                NaN
# 1                 テツノツツミ             5516.0
# 2                 テツノツツミ             5516.0
# 3                 テツノツツミ             5516.0
# 4                 テツノツツミ             6426.0
# 5                 テツノツツミ             6426.0
# 6                 テツノツツミ             6426.0
# 7                 テツノツツミ             6426.0
# 8                 テツノツツミ             6426.0
# 9                 テツノツツミ             6426.0
# 10               霊獣ランドロス             9638.0
# 11               霊獣ランドロス             9638.0
# 12               霊獣ランドロス             9638.0
# 13               霊獣ランドロス             9638.0
# 14               霊獣ランドロス            11141.0
# 15               霊獣ランドロス            11141.0
# 16              ガラルヤドキング            12631.0
# 17              ガラルヤドキング            14047.0
# 18              ガラルヤドキング            14047.0
# 19              ガラルヤドキング            14789.0
# 20              ガラルヤドキング            14789.0
# 21                テツノツツミ            16239.0
# 22                テツノツツミ            16239.0
# 23                テツノツツミ            16239.0
# 24                テツノツツミ            16239.0
# 25              ガラルヤドキング            17178.0
# 26              ガラルヤドキング            17178.0
# 27              ガラルヤドキング            17178.0
# 28                テツノツツミ                NaN
# 29                テツノツツミ                NaN

# %%
# Find fainted pokemon messages
df_messages2['fainted_pokemon_type'] = None
df_messages2.loc[df_messages2.message.str.contains('.* fainted!'), 'fainted_pokemon_type'] = 'Your Pokemon Fainted'
df_messages2.loc[df_messages2.message.str.contains('The opposing .* fainted!'), 'fainted_pokemon_type'] = 'Opponent Pokemon Fainted'

# %%
# Keep only rows with fainted pokemon
df_messages2 = df_messages2.dropna(subset=['fainted_pokemon_type'])

# Join fainted pokemon messages to the battle log
df_in_battle_pokemon = df_in_battle_pokemon.merge(
    df_messages2[['battle_id', 'turn', 'fainted_pokemon_type']], 
    on=['battle_id', 'turn'],
    how='left'
)

# %%
df_messages2
# Out:
#                                 battle_id  frame_number  \
# 8    b65de106-caf1-5d60-a127-499242a0e687          5868
# 27   b65de106-caf1-5d60-a127-499242a0e687         16545
# 29   b65de106-caf1-5d60-a127-499242a0e687         17339
# 82   688a2326-1fe5-5cea-935f-634c363e86e2         31480
# 118  688a2326-1fe5-5cea-935f-634c363e86e2         39843
# 121  688a2326-1fe5-5cea-935f-634c363e86e2         42191
# 184  29931ceb-1bef-5729-96a0-c0d235580ab4         67314
# 193  29931ceb-1bef-5729-96a0-c0d235580ab4         68563
# 205  29931ceb-1bef-5729-96a0-c0d235580ab4         70839
#
#                                  message  turn your_pokemon_name  \
# 8                     Dragapult fainted!   2.0             ドラパルト
# 27        The opposing ヤ ド キ ング fainted!  11.0            ハバタクカミ
# 29   The opposing 7 デ ツ ノ ツ ツ ミ fainted!  12.0            ハバタクカミ
# 82       The opposing 八 バ タク カミ fainted!   8.0             ヒードラン
# 118     The opposing ウツ ウー ラオ ス fainted!  15.0          ヒスイドレディア
# 121      The opposing Chien-Pao fainted!  16.0          ヒスイドレディア
# 184                   Dragapult fainted!  19.0             ドラパルト
# 193        The opposing セグ レイ ブ fainted!  20.0             ヒードラン
# 205           The opposing メオ ー fainted!  22.0             ヒードラン
#
#     opponent_pokemon_name  next_frame_number      fainted_pokemon_type
# 8                  テツノツツミ             6426.0      Your Pokemon Fainted
# 27               ガラルヤドキング            17178.0  Opponent Pokemon Fainted
# 29                 テツノツツミ                NaN  Opponent Pokemon Fainted
# 82                 ハバタクカミ            32936.0  Opponent Pokemon Fainted
# 118                 ウーラオス            40426.0  Opponent Pokemon Fainted
# 121                 パオジアン                NaN  Opponent Pokemon Fainted
# 184                 セグレイブ            68211.0      Your Pokemon Fainted
# 193                 セグレイブ            69818.0  Opponent Pokemon Fainted
# 205                   ヌオー                NaN  Opponent Pokemon Fainted

# %%
# Add a 'fainted_pokemon_side' column
df_in_battle_pokemon['fainted_pokemon_side'] = 'Unknown'
df_in_battle_pokemon.loc[df_in_battle_pokemon.fainted_pokemon_type == 'Your Pokemon Fainted', 'fainted_pokemon_side'] = 'Opponent Pokemon Win'
df_in_battle_pokemon.loc[df_in_battle_pokemon.fainted_pokemon_type == 'Opponent Pokemon Fainted', 'fainted_pokemon_side'] = 'Your Pokemon Win'

# %%
df_in_battle_pokemon
# Out:
#                                battle_id  turn  frame_number  \
# 0   29931ceb-1bef-5729-96a0-c0d235580ab4     1         50149
# 1   29931ceb-1bef-5729-96a0-c0d235580ab4     2         50428
# 2   29931ceb-1bef-5729-96a0-c0d235580ab4     3         51422
# 3   29931ceb-1bef-5729-96a0-c0d235580ab4     4         51599
# 4   29931ceb-1bef-5729-96a0-c0d235580ab4     5         52263
# 5   29931ceb-1bef-5729-96a0-c0d235580ab4     6         53478
# 6   29931ceb-1bef-5729-96a0-c0d235580ab4     7         54195
# 7   29931ceb-1bef-5729-96a0-c0d235580ab4     8         54798
# 8   29931ceb-1bef-5729-96a0-c0d235580ab4     9         56182
# 9   29931ceb-1bef-5729-96a0-c0d235580ab4    10         57553
# 10  29931ceb-1bef-5729-96a0-c0d235580ab4    11         58400
# 11  29931ceb-1bef-5729-96a0-c0d235580ab4    12         59706
# 12  29931ceb-1bef-5729-96a0-c0d235580ab4    13         60721
# 13  29931ceb-1bef-5729-96a0-c0d235580ab4    14         60969
# 14  29931ceb-1bef-5729-96a0-c0d235580ab4    15         62738
# 15  29931ceb-1bef-5729-96a0-c0d235580ab4    16         64440
# 16  29931ceb-1bef-5729-96a0-c0d235580ab4    17         64977
# 17  29931ceb-1bef-5729-96a0-c0d235580ab4    18         66339
# 18  29931ceb-1bef-5729-96a0-c0d235580ab4    19         67086
# 19  29931ceb-1bef-5729-96a0-c0d235580ab4    20         68211
# 20  29931ceb-1bef-5729-96a0-c0d235580ab4    21         69818
# 21  29931ceb-1bef-5729-96a0-c0d235580ab4    22         70644
# 22  688a2326-1fe5-5cea-935f-634c363e86e2     1         23532
# 23  688a2326-1fe5-5cea-935f-634c363e86e2     2         23970
# 24  688a2326-1fe5-5cea-935f-634c363e86e2     3         24973
# 25  688a2326-1fe5-5cea-935f-634c363e86e2     4         26875
# 26  688a2326-1fe5-5cea-935f-634c363e86e2     5         28075
# 27  688a2326-1fe5-5cea-935f-634c363e86e2     6         28799
# 28  688a2326-1fe5-5cea-935f-634c363e86e2     7         29578
# 29  688a2326-1fe5-5cea-935f-634c363e86e2     8         30890
# 30  688a2326-1fe5-5cea-935f-634c363e86e2     9         32936
# 31  688a2326-1fe5-5cea-935f-634c363e86e2    10         33321
# 32  688a2326-1fe5-5cea-935f-634c363e86e2    11         34720
# 33  688a2326-1fe5-5cea-935f-634c363e86e2    12         35698
# 34  688a2326-1fe5-5cea-935f-634c363e86e2    13         36409
# 35  688a2326-1fe5-5cea-935f-634c363e86e2    14         37378
# 36  688a2326-1fe5-5cea-935f-634c363e86e2    15         38851
# 37  688a2326-1fe5-5cea-935f-634c363e86e2    16         40426
# 38  b65de106-caf1-5d60-a127-499242a0e687     1          5012
# 39  b65de106-caf1-5d60-a127-499242a0e687     2          5516
# 40  b65de106-caf1-5d60-a127-499242a0e687     3          6426
# 41  b65de106-caf1-5d60-a127-499242a0e687     4          7870
# 42  b65de106-caf1-5d60-a127-499242a0e687     5          9638
# 43  b65de106-caf1-5d60-a127-499242a0e687     6         11141
# 44  b65de106-caf1-5d60-a127-499242a0e687     7         11879
# 45  b65de106-caf1-5d60-a127-499242a0e687     8         12631
# 46  b65de106-caf1-5d60-a127-499242a0e687     9         14047
# 47  b65de106-caf1-5d60-a127-499242a0e687    10         14789
# 48  b65de106-caf1-5d60-a127-499242a0e687    11         16239
# 49  b65de106-caf1-5d60-a127-499242a0e687    12         17178
#
#    your_pokemon_name opponent_pokemon_name  next_frame_number  \
# 0              ドラパルト                 オーロンゲ            50428.0
# 1              ドラパルト                 オーロンゲ            51422.0
# 2              ヒードラン                 オーロンゲ            51599.0
# 3              ヒードラン                 オーロンゲ            52263.0
# 4              ヒードラン                   ヌオー            53478.0
# 5              ドラパルト                   ヌオー            54195.0
# 6              ドラパルト                   ヌオー            54798.0
# 7              ドラパルト                 オーロンゲ            56182.0
# 8           ヒスイドレディア                 オーロンゲ            57553.0
# 9           ヒスイドレディア                 オーロンゲ            58400.0
# 10          ヒスイドレディア                 オーロンゲ            59706.0
# 11          ヒスイドレディア                 セグレイブ            60721.0
# 12          ヒスイドレディア                   ヌオー            60969.0
# 13          ヒスイドレディア                   ヌオー            62738.0
# 14          ヒスイドレディア                   ヌオー            64440.0
# 15          ヒスイドレディア                   ヌオー            64977.0
# 16          ヒスイドレディア                   ヌオー            66339.0
# 17             ドラパルト                   ヌオー            67086.0
# 18             ドラパルト                 セグレイブ            68211.0
# 19             ヒードラン                 セグレイブ            69818.0
# 20             ヒードラン                   ヌオー            70644.0
# 21             ヒードラン                   ヌオー                NaN
# 22             ドラパルト                 パオジアン            23970.0
# 23             ドラパルト                 パオジアン            24973.0
# 24             ドラパルト                ハバタクカミ            26875.0
# 25             ヒードラン                ハバタクカミ            28075.0
# 26             ヒードラン                ハバタクカミ            28799.0
# 27             ヒードラン                ハバタクカミ            29578.0
# 28             ヒードラン                ハバタクカミ            30890.0
# 29             ヒードラン                ハバタクカミ            32936.0
# 30             ヒードラン                 ウーラオス            33321.0
# 31             ヒードラン                 ウーラオス            34720.0
# 32             ドラパルト                 ウーラオス            35698.0
# 33             ドラパルト                 ウーラオス            36409.0
# 34             ドラパルト                 ウーラオス            37378.0
# 35             ドラパルト                 ウーラオス            38851.0
# 36          ヒスイドレディア                 ウーラオス            40426.0
# 37          ヒスイドレディア                 パオジアン                NaN
# 38             ドラパルト                テツノツツミ             5516.0
# 39             ドラパルト                テツノツツミ             6426.0
# 40          ヒスイドレディア                テツノツツミ             7870.0
# 41          ヒスイドレディア               霊獣ランドロス             9638.0
# 42          ヒスイドレディア               霊獣ランドロス            11141.0
# 43          ヒスイドレディア              ガラルヤドキング            11879.0
# 44          ヒスイドレディア              ガラルヤドキング            12631.0
# 45          ヒスイドレディア              ガラルヤドキング            14047.0
# 46          ヒスイドレディア              ガラルヤドキング            14789.0
# 47          ヒスイドレディア                テツノツツミ            16239.0
# 48            ハバタクカミ              ガラルヤドキング            17178.0
# 49            ハバタクカミ                テツノツツミ                NaN
#
#         fainted_pokemon_type  fainted_pokemon_side
# 0                        NaN               Unknown
# 1                        NaN               Unknown
# 2                        NaN               Unknown
# 3                        NaN               Unknown
# 4                        NaN               Unknown
# 5                        NaN               Unknown
# 6                        NaN               Unknown
# 7                        NaN               Unknown
# 8                        NaN               Unknown
# 9                        NaN               Unknown
# 10                       NaN               Unknown
# 11                       NaN               Unknown
# 12                       NaN               Unknown
# 13                       NaN               Unknown
# 14                       NaN               Unknown
# 15                       NaN               Unknown
# 16                       NaN               Unknown
# 17                       NaN               Unknown
# 18      Your Pokemon Fainted  Opponent Pokemon Win
# 19  Opponent Pokemon Fainted      Your Pokemon Win
# 20                       NaN               Unknown
# 21  Opponent Pokemon Fainted      Your Pokemon Win
# 22                       NaN               Unknown
# 23                       NaN               Unknown
# 24                       NaN               Unknown
# 25                       NaN               Unknown
# 26                       NaN               Unknown
# 27                       NaN               Unknown
# 28                       NaN               Unknown
# 29  Opponent Pokemon Fainted      Your Pokemon Win
# 30                       NaN               Unknown
# 31                       NaN               Unknown
# 32                       NaN               Unknown
# 33                       NaN               Unknown
# 34                       NaN               Unknown
# 35                       NaN               Unknown
# 36  Opponent Pokemon Fainted      Your Pokemon Win
# 37  Opponent Pokemon Fainted      Your Pokemon Win
# 38                       NaN               Unknown
# 39      Your Pokemon Fainted  Opponent Pokemon Win
# 40                       NaN               Unknown
# 41                       NaN               Unknown
# 42                       NaN               Unknown
# 43                       NaN               Unknown
# 44                       NaN               Unknown
# 45                       NaN               Unknown
# 46                       NaN               Unknown
# 47                       NaN               Unknown
# 48  Opponent Pokemon Fainted      Your Pokemon Win
# 49  Opponent Pokemon Fainted      Your Pokemon Win

# %%
df_in_battle_pokemon.query("fainted_pokemon_side != 'Unknown'")
# Out:
#                                battle_id  turn  frame_number  \
# 18  29931ceb-1bef-5729-96a0-c0d235580ab4    19         67086
# 19  29931ceb-1bef-5729-96a0-c0d235580ab4    20         68211
# 21  29931ceb-1bef-5729-96a0-c0d235580ab4    22         70644
# 29  688a2326-1fe5-5cea-935f-634c363e86e2     8         30890
# 36  688a2326-1fe5-5cea-935f-634c363e86e2    15         38851
# 37  688a2326-1fe5-5cea-935f-634c363e86e2    16         40426
# 39  b65de106-caf1-5d60-a127-499242a0e687     2          5516
# 48  b65de106-caf1-5d60-a127-499242a0e687    11         16239
# 49  b65de106-caf1-5d60-a127-499242a0e687    12         17178
#
#    your_pokemon_name opponent_pokemon_name  next_frame_number  \
# 18             ドラパルト                 セグレイブ            68211.0
# 19             ヒードラン                 セグレイブ            69818.0
# 21             ヒードラン                   ヌオー                NaN
# 29             ヒードラン                ハバタクカミ            32936.0
# 36          ヒスイドレディア                 ウーラオス            40426.0
# 37          ヒスイドレディア                 パオジアン                NaN
# 39             ドラパルト                テツノツツミ             6426.0
# 48            ハバタクカミ              ガラルヤドキング            17178.0
# 49            ハバタクカミ                テツノツツミ                NaN
#
#         fainted_pokemon_type  fainted_pokemon_side
# 18      Your Pokemon Fainted  Opponent Pokemon Win
# 19  Opponent Pokemon Fainted      Your Pokemon Win
# 21  Opponent Pokemon Fainted      Your Pokemon Win
# 29  Opponent Pokemon Fainted      Your Pokemon Win
# 36  Opponent Pokemon Fainted      Your Pokemon Win
# 37  Opponent Pokemon Fainted      Your Pokemon Win
# 39      Your Pokemon Fainted  Opponent Pokemon Win
# 48  Opponent Pokemon Fainted      Your Pokemon Win
# 49  Opponent Pokemon Fainted      Your Pokemon Win

# %%
df_in_battle_pokemon.query("fainted_pokemon_side != 'Unknown'").to_dict(orient="records")
# Out:
# [{'battle_id': '29931ceb-1bef-5729-96a0-c0d235580ab4',
#   'turn': 19,
#   'frame_number': 67086,
#   'your_pokemon_name': 'ドラパルト',
#   'opponent_pokemon_name': 'セグレイブ',
#   'next_frame_number': 68211.0,
#   'fainted_pokemon_type': 'Your Pokemon Fainted',
#   'fainted_pokemon_side': 'Opponent Pokemon Win'},
#  {'battle_id': '29931ceb-1bef-5729-96a0-c0d235580ab4',
#   'turn': 20,
#   'frame_number': 68211,
#   'your_pokemon_name': 'ヒードラン',
#   'opponent_pokemon_name': 'セグレイブ',
#   'next_frame_number': 69818.0,
#   'fainted_pokemon_type': 'Opponent Pokemon Fainted',
#   'fainted_pokemon_side': 'Your Pokemon Win'},
#  {'battle_id': '29931ceb-1bef-5729-96a0-c0d235580ab4',
#   'turn': 22,
#   'frame_number': 70644,
#   'your_pokemon_name': 'ヒードラン',
#   'opponent_pokemon_name': 'ヌオー',
#   'next_frame_number': nan,
#   'fainted_pokemon_type': 'Opponent Pokemon Fainted',
#   'fainted_pokemon_side': 'Your Pokemon Win'},
#  {'battle_id': '688a2326-1fe5-5cea-935f-634c363e86e2',
#   'turn': 8,
#   'frame_number': 30890,
#   'your_pokemon_name': 'ヒードラン',
#   'opponent_pokemon_name': 'ハバタクカミ',
#   'next_frame_number': 32936.0,
#   'fainted_pokemon_type': 'Opponent Pokemon Fainted',
#   'fainted_pokemon_side': 'Your Pokemon Win'},
#  {'battle_id': '688a2326-1fe5-5cea-935f-634c363e86e2',
#   'turn': 15,
#   'frame_number': 38851,
#   'your_pokemon_name': 'ヒスイドレディア',
#   'opponent_pokemon_name': 'ウーラオス',
#   'next_frame_number': 40426.0,
#   'fainted_pokemon_type': 'Opponent Pokemon Fainted',
#   'fainted_pokemon_side': 'Your Pokemon Win'},
#  {'battle_id': '688a2326-1fe5-5cea-935f-634c363e86e2',
#   'turn': 16,
#   'frame_number': 40426,
#   'your_pokemon_name': 'ヒスイドレディア',
#   'opponent_pokemon_name': 'パオジアン',
#   'next_frame_number': nan,
#   'fainted_pokemon_type': 'Opponent Pokemon Fainted',
#   'fainted_pokemon_side': 'Your Pokemon Win'},
#  {'battle_id': 'b65de106-caf1-5d60-a127-499242a0e687',
#   'turn': 2,
#   'frame_number': 5516,
#   'your_pokemon_name': 'ドラパルト',
#   'opponent_pokemon_name': 'テツノツツミ',
#   'next_frame_number': 6426.0,
#   'fainted_pokemon_type': 'Your Pokemon Fainted',
#   'fainted_pokemon_side': 'Opponent Pokemon Win'},
#  {'battle_id': 'b65de106-caf1-5d60-a127-499242a0e687',
#   'turn': 11,
#   'frame_number': 16239,
#   'your_pokemon_name': 'ハバタクカミ',
#   'opponent_pokemon_name': 'ガラルヤドキング',
#   'next_frame_number': 17178.0,
#   'fainted_pokemon_type': 'Opponent Pokemon Fainted',
#   'fainted_pokemon_side': 'Your Pokemon Win'},
#  {'battle_id': 'b65de106-caf1-5d60-a127-499242a0e687',
#   'turn': 12,
#   'frame_number': 17178,
#   'your_pokemon_name': 'ハバタクカミ',
#   'opponent_pokemon_name': 'テツノツツミ',
#   'next_frame_number': nan,
#   'fainted_pokemon_type': 'Opponent Pokemon Fainted',
#   'fainted_pokemon_side': 'Your Pokemon Win'}]

# %%
df_in_battle_pokemon = pd.DataFrame([obj.__dict__ for obj in modified_in_battle_pokemons])
df_messages = pd.DataFrame([obj.__dict__ for obj in modified_messages])
df_in_battle_pokemon = df_in_battle_pokemon.sort_values(
    by=["battle_id", "turn"]
)
df_in_battle_pokemon["next_frame_number"] = df_in_battle_pokemon.groupby(
    "battle_id"
)["frame_number"].shift(-1)

# Join the message log to the battle log
df_messages2 = pd.merge_asof(
    df_messages.sort_values("frame_number"),
    df_in_battle_pokemon.sort_values("frame_number"),
    left_on="frame_number",
    right_on="frame_number",
    by="battle_id",
    direction="backward",
)
df_messages2["fainted_pokemon_type"] = None
df_messages2.loc[
    df_messages2.message.str.contains(".* fainted!"), "fainted_pokemon_type"
] = "Your Pokemon Fainted"
df_messages2.loc[
    df_messages2.message.str.contains("The opposing .* fainted!"),
    "fainted_pokemon_type",
] = "Opponent Pokemon Fainted"
# Keep only rows with fainted pokemon
df_messages2 = df_messages2.dropna(subset=["fainted_pokemon_type"])

# Join fainted pokemon messages to the battle log
df_in_battle_pokemon = df_in_battle_pokemon.merge(
    df_messages2[["battle_id", "turn", "fainted_pokemon_type"]],
    on=["battle_id", "turn"],
    how="left",
)
# Add a 'fainted_pokemon_side' column
df_in_battle_pokemon["fainted_pokemon_side"] = "Unknown"
df_in_battle_pokemon.loc[
    df_in_battle_pokemon.fainted_pokemon_type == "Your Pokemon Fainted",
    "fainted_pokemon_side",
] = "Opponent Pokemon Win"
df_in_battle_pokemon.loc[
    df_in_battle_pokemon.fainted_pokemon_type == "Opponent Pokemon Fainted",
    "fainted_pokemon_side",
] = "Your Pokemon Win"
stats = df_in_battle_pokemon.query("fainted_pokemon_side != 'Unknown'")
stats = stats.drop_duplicates()
stats
# Out:
#                                battle_id  turn  frame_number  \
# 18  29931ceb-1bef-5729-96a0-c0d235580ab4    19         67086
# 19  29931ceb-1bef-5729-96a0-c0d235580ab4    20         68211
# 21  29931ceb-1bef-5729-96a0-c0d235580ab4    22         70644
# 29  688a2326-1fe5-5cea-935f-634c363e86e2     8         30890
# 36  688a2326-1fe5-5cea-935f-634c363e86e2    15         38851
# 37  688a2326-1fe5-5cea-935f-634c363e86e2    16         40426
# 39  b65de106-caf1-5d60-a127-499242a0e687     2          5516
# 48  b65de106-caf1-5d60-a127-499242a0e687    11         16239
# 49  b65de106-caf1-5d60-a127-499242a0e687    12         17178
#
#    your_pokemon_name opponent_pokemon_name  next_frame_number  \
# 18             ドラパルト                 セグレイブ            68211.0
# 19             ヒードラン                 セグレイブ            69818.0
# 21             ヒードラン                   ヌオー                NaN
# 29             ヒードラン                ハバタクカミ            32936.0
# 36          ヒスイドレディア                 ウーラオス            40426.0
# 37          ヒスイドレディア                 パオジアン                NaN
# 39             ドラパルト                テツノツツミ             6426.0
# 48            ハバタクカミ              ガラルヤドキング            17178.0
# 49            ハバタクカミ                テツノツツミ                NaN
#
#         fainted_pokemon_type  fainted_pokemon_side
# 18      Your Pokemon Fainted  Opponent Pokemon Win
# 19  Opponent Pokemon Fainted      Your Pokemon Win
# 21  Opponent Pokemon Fainted      Your Pokemon Win
# 29  Opponent Pokemon Fainted      Your Pokemon Win
# 36  Opponent Pokemon Fainted      Your Pokemon Win
# 37  Opponent Pokemon Fainted      Your Pokemon Win
# 39      Your Pokemon Fainted  Opponent Pokemon Win
# 48  Opponent Pokemon Fainted      Your Pokemon Win
# 49  Opponent Pokemon Fainted      Your Pokemon Win

# %%
from matplotlib import pyplot as plt

video.set(cv2.CAP_PROP_POS_FRAMES, 31317)
ret, frame = video.read()
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_RGB2BGR)) # [500:600, 150:800]
plt.show()

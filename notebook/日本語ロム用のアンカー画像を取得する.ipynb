# %%
import cv2
from tqdm.auto import tqdm
from matplotlib import pyplot as plt

# %%
video_path = "../video/日本語_NjSc4C6QwMk.mp4"
video = cv2.VideoCapture(video_path)

# %% [markdown]
# ## 選出順と選出決定

# %%
video.set(cv2.CAP_PROP_POS_FRAMES, 5590)
ret, frame = video.read()
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_RGB2BGR))
plt.show()

# %%
frame.shape
# Out:
# (1080, 1920, 3)

# %%
117+616
# Out:
# 733

# %%
# 選出順
# POKEMON_SELECT_NUMBER_WINDOW1 = (148, 198, 748, 928)
# POKEMON_SELECT_NUMBER_WINDOW2 = (265, 315, 748, 928)
# POKEMON_SELECT_NUMBER_WINDOW3 = (382, 432, 748, 928)
# POKEMON_SELECT_NUMBER_WINDOW4 = (499, 549, 748, 928)
# POKEMON_SELECT_NUMBER_WINDOW5 = (616, 666, 748, 928)
# POKEMON_SELECT_NUMBER_WINDOW6 = (733, 783, 748, 928)

plt.imshow(cv2.cvtColor(frame[148:198, 748:928], cv2.COLOR_RGB2BGR))
plt.show()

# %%
plt.imshow(cv2.cvtColor(frame[265:315, 748:928], cv2.COLOR_RGB2BGR))
plt.show()

# %%
plt.imshow(cv2.cvtColor(frame[499:549, 748:928], cv2.COLOR_RGB2BGR))
plt.show()

# %%
cv2.imwrite("../template_images/japanese_general_templates/second.png", frame[499:549, 748:928])
# Out:
# True

# %%
# 決定
# POKEMON_SELECT_DONE_WINDOW = (560, 610, 90, 503)

plt.imshow(cv2.cvtColor(frame[855:930, 145:805], cv2.COLOR_RGB2BGR))
plt.show()

# %%
cv2.imwrite("../template_images/japanese_general_templates/select_done.png", frame[855:930, 145:805])
# Out:
# True

# %% [markdown]
# ## standing by

# %%
video.set(cv2.CAP_PROP_POS_FRAMES, 5650)
ret, frame = video.read()
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_RGB2BGR))
plt.show()

# %%
plt.imshow(cv2.cvtColor(frame[885:935, 260:700], cv2.COLOR_RGB2BGR))
plt.show()

# %%
cv2.imwrite("../template_images/japanese_general_templates/standing_by.png", frame[885:935, 260:700])
# Out:
# True

# %% [markdown]
# ## ランク表示

# %%
video.set(cv2.CAP_PROP_POS_FRAMES, 25720)
ret, frame = video.read()
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_RGB2BGR))
plt.show()

# %%
plt.imshow(cv2.cvtColor(frame[360:515, 710:1210], cv2.COLOR_RGB2BGR))
plt.show()

# %%
cv2.imwrite("../template_images/japanese_general_templates/ranking.png", frame[360:515, 710:1210])
# Out:
# True

# %% [markdown]
# その他確認

# %%
plt.imshow(cv2.cvtColor(frame[580:680, 750:1200], cv2.COLOR_RGB2BGR))
plt.show()

# %%
video.set(cv2.CAP_PROP_POS_FRAMES, 25100)
ret, frame = video.read()
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_RGB2BGR))
plt.show()

# %%
plt.imshow(cv2.cvtColor(frame[950:1050, 430:750], cv2.COLOR_RGB2BGR))
plt.show()

# %%
cv2.imwrite("../template_images/general_templates/win2.png", frame[950:1050, 430:750])
# Out:
# True

# %%
video.set(cv2.CAP_PROP_POS_FRAMES, 51800)
ret, frame = video.read()
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_RGB2BGR))
plt.show()

# %%
cv2.imwrite("../template_images/japanese_general_templates/lost.png", frame[950:1050, 430:750])
# Out:
# True

# %%
video.set(cv2.CAP_PROP_POS_FRAMES, 23100)
ret, frame = video.read()
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_RGB2BGR))
plt.show()

# %%
plt.imshow(cv2.cvtColor(frame[880:940, 80:320], cv2.COLOR_RGB2BGR))
plt.show()

# %%
cv2.imwrite("../template_images/labeled_pokemon_name_window_templates/カバルドン_1920.png", frame[880:940, 80:320])
# Out:
# True

# %%
plt.imshow(cv2.cvtColor(frame[90:150, 1530:1750], cv2.COLOR_RGB2BGR))
plt.show()

# %%
plt.imshow(cv2.cvtColor(frame[50:90, 1560:1670], cv2.COLOR_RGB2BGR))
plt.show()

# %%
cv2.imwrite("../template_images/japanese_general_templates/level_50.png", frame[50:90, 1560:1670])
# Out:
# True

# %%
video.set(cv2.CAP_PROP_POS_FRAMES, 5650)
ret, frame = video.read()
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_RGB2BGR))
plt.show()

# %%
plt.imshow(cv2.cvtColor(frame[230:330, 275:380], cv2.COLOR_RGB2BGR))
plt.show()

# %%
cv2.imwrite("../template_images/labeled_pokemon_templates/カバルドン_1920.png", frame[230:330, 275:380])
# Out:
# True

# %%
plt.imshow(cv2.cvtColor(frame[331:431, 275:380], cv2.COLOR_RGB2BGR))
plt.show()

# %%
plt.imshow(cv2.cvtColor(frame[735:835, 1240:1345], cv2.COLOR_RGB2BGR))
plt.show()

# %%
video.set(cv2.CAP_PROP_POS_FRAMES, 24000)
ret, frame = video.read()
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_RGB2BGR))
plt.show()

# %%
plt.imshow(cv2.cvtColor(frame[800:840, 285:330], cv2.COLOR_RGB2BGR))
plt.show()

# %%
plt.imshow(cv2.cvtColor(frame[780:930, 250:1500], cv2.COLOR_RGB2BGR))
plt.show()

# %% [markdown]
# ## 大きいサイズでも faiss はいける？

# %%
import faiss
import cloudpickle
import imgsim
import cv2

vtr = imgsim.Vectorizer()

trained_faiss_index = faiss.read_index(
    "../model/pokemon_image_faiss/pokemon_faiss_index"
)
trained_vector_index = cloudpickle.load(
    open("../model/pokemon_image_faiss/pokemon_faiss_index_vector_index", "rb")
)

img = cv2.imread("../template_images/labeled_pokemon_templates/カバルドン_1920.png")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
vec = vtr.vectorize(img)
vec = np.reshape(vec, (1, vec.shape[0]))
scores, indexes = trained_faiss_index.search(vec, 10)
for score, idx in zip(scores[0], indexes[0]):
    if score < 200:
        print(trained_vector_index[idx].split("_")[0])
# Out:
# カバルドン
# カバルドン
# コータス
# トリトドン
# バンバドロ
# ウルガモス
# ウルガモス
# ウルガモス

# %%
scores
# Out:
# array([[ 41.350666,  59.384064, 147.28003 , 149.82867 , 173.3252  ,
#         174.42897 , 177.99695 , 187.55957 , 205.36223 , 219.80875 ]],
#       dtype=float32)

# %% [markdown]
# 動いた

# %% [markdown]
# ## 大きい画像に対するテンプレートマッチングは動く？

# %%
import glob

battle_pokemon_name_window_template_paths = glob.glob(
    "../template_images/labeled_pokemon_name_window_templates/*.png"
)
battle_pokemon_name_window_templates = {}
for path in battle_pokemon_name_window_template_paths:
    _gray_image = cv2.imread(path, 0)
    battle_pokemon_name_window_templates[
        path.split("/")[-1].split(".")[0]
    ] = _gray_image

# %%
gray_name_window = cv2.imread("../template_images/labeled_pokemon_name_window_templates/カバルドン_1920.png", 0)

score_results = {}
for pokemon_name, template in battle_pokemon_name_window_templates.items():
    res = cv2.matchTemplate(gray_name_window, template, cv2.TM_CCOEFF_NORMED)
    score = cv2.minMaxLoc(res)[1]
    score_results[pokemon_name] = score

# %%
score_results["カバルドン_2"]
# Out:
# 0.2377728819847107

# %% [markdown]
# 動かなかった...
